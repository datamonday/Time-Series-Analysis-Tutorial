# %%
print('开始执行try语句···')
try:
    # try中放置的是有可能出现错误的代码
    print(10/0)
except:
    # except中放置的是出错以后的处理防暑
    print('哈哈哈，出错了~~~')
else:
    print('程序正常执行没有错误')    
print('执行结束!')
# Out:
# 开始执行try语句···
# 哈哈哈，出错了~~~
# 执行结束!
